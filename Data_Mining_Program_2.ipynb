# %% [markdown]
# ## Reading data

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

# %% [markdown]
# Data is gotten from here: https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction

# %%
drive.mount('/content/drive', force_remount=True )
os.chdir('drive/My Drive/' ) #enter your own filepath here
df = pd.read_csv('heart.csv')
print( df.shape )
# Out:
# Mounted at /content/drive
# (918, 12)

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %% [markdown]
# ## Cleaning data

# %%
#let's look at the datatypes for each column
for x in df.columns:
  print( str( type( df[x].iloc[0] ) ) + ": " + x )
# Out:
# <class 'numpy.int64'>: Age
# <class 'str'>: Sex
# <class 'str'>: ChestPainType
# <class 'numpy.int64'>: RestingBP
# <class 'numpy.int64'>: Cholesterol
# <class 'numpy.int64'>: FastingBS
# <class 'str'>: RestingECG
# <class 'numpy.int64'>: MaxHR
# <class 'str'>: ExerciseAngina
# <class 'numpy.float64'>: Oldpeak
# <class 'str'>: ST_Slope
# <class 'numpy.int64'>: HeartDisease

# %%
#non-null values in each column
df.count()
# Out:
# Age               918
# Sex               918
# ChestPainType     918
# RestingBP         918
# Cholesterol       918
# FastingBS         918
# RestingECG        918
# MaxHR             918
# ExerciseAngina    918
# Oldpeak           918
# ST_Slope          918
# HeartDisease      918
# dtype: int64

# %%
for x in df.columns:
  print( df[x].value_counts() )
# Out:
# Age
# 54    51
# 58    42
# 55    41
# 56    38
# 57    38
# 52    36
# 62    35
# 59    35
# 51    35
# 53    33
# 60    32
# 48    31
# 61    31
# 63    30
# 50    25
# 41    24
# 43    24
# 46    24
# 64    22
# 49    21
# 65    21
# 47    19
# 44    19
# 45    18
# 42    18
# 38    16
# 67    15
# 39    15
# 40    13
# 69    13
# 66    13
# 37    11
# 35    11
# 68    10
# 74     7
# 70     7
# 34     7
# 36     6
# 32     5
# 71     5
# 72     4
# 75     3
# 29     3
# 31     2
# 33     2
# 77     2
# 76     2
# 30     1
# 28     1
# 73     1
# Name: count, dtype: int64
# Sex
# M    725
# F    193
# Name: count, dtype: int64
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64
# RestingBP
# 120    132
# 130    118
# 140    107
# 110     58
# 150     55
#       ...
# 101      1
# 117      1
# 192      1
# 129      1
# 164      1
# Name: count, Length: 67, dtype: int64
# Cholesterol
# 0      172
# 254     11
# 220     10
# 223     10
# 204      9
#       ...
# 353      1
# 278      1
# 157      1
# 176      1
# 131      1
# Name: count, Length: 222, dtype: int64
# FastingBS
# 0    704
# 1    214
# Name: count, dtype: int64
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64
# MaxHR
# 150    43
# 140    41
# 120    36
# 130    33
# 160    25
#        ..
# 192     1
# 195     1
# 194     1
# 187     1
# 202     1
# Name: count, Length: 119, dtype: int64
# ExerciseAngina
# N    547
# Y    371
# Name: count, dtype: int64
# Oldpeak
#  0.0    368
#  1.0     86
#  2.0     76
#  1.5     53
#  3.0     28
#  1.2     26
#  0.2     22
#  0.5     19
#  1.4     18
#  1.8     17
#  2.5     16
#  1.6     16
#  0.8     16
#  0.1     14
#  0.6     14
#  0.3     11
#  0.4     11
#  4.0      8
#  2.8      7
#  0.7      7
#  1.3      7
#  1.1      7
#  2.6      7
#  1.9      7
#  1.7      6
#  2.2      5
#  3.6      4
#  0.9      4
#  2.4      4
#  3.4      3
#  2.1      2
#  3.2      2
#  2.3      2
# -1.0      2
#  4.2      2
#  3.5      2
# -0.1      2
# -0.5      2
#  5.0      1
# -0.7      1
# -0.8      1
# -1.5      1
# -0.9      1
# -2.6      1
# -1.1      1
#  3.7      1
# -2.0      1
#  3.1      1
#  5.6      1
#  3.8      1
#  2.9      1
#  6.2      1
#  4.4      1
# Name: count, dtype: int64
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Age                 int64
# Sex                 int64
# ChestPainType       int64
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG          int64
# MaxHR               int64
# ExerciseAngina      int64
# Oldpeak           float64
# ST_Slope            int64
# HeartDisease        int64
# dtype: object

# %%
#Gonna have to change this manually or find a way to do it without explicitly writing column names (Done :)
from sklearn.preprocessing import LabelEncoder

categorical_columns = df.select_dtypes(include=['object']).columns


for col in categorical_columns:
    df[col] = LabelEncoder().fit_transform(df[col])

# %% [markdown]
# ## Models

# %% [markdown]
# Splitting data into test and train

# %%
from sklearn.model_selection import train_test_split


X = df.drop('HeartDisease', axis = 1)
y = df['HeartDisease']


X_train, X_test, y_train, y_test = train_test_split(
  X,y , random_state=42,test_size=0.2, shuffle=True)

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler().fit(X_train)
X_scaled = scaler.transform(X_train)

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

K = []
training = []
test = []
scores = {}

for k in range(2, 21):
    clf = KNeighborsClassifier(n_neighbors = k)
    clf.fit(X_train, y_train)

    training_score = clf.score(X_train, y_train)
    test_score = clf.score(X_test, y_test)
    K.append(k)

    training.append(training_score)
    test.append(test_score)
    scores[k] = [training_score, test_score]

# %%
for keys, values in scores.items():
    print(keys, ':', values)
# Out:
# 2 : [0.8351498637602179, 0.5978260869565217]
# 3 : [0.8201634877384196, 0.6521739130434783]
# 4 : [0.7970027247956403, 0.6793478260869565]
# 5 : [0.7929155313351499, 0.7010869565217391]
# 6 : [0.776566757493188, 0.6630434782608695]
# 7 : [0.7861035422343324, 0.6630434782608695]
# 8 : [0.7861035422343324, 0.6413043478260869]
# 9 : [0.7806539509536785, 0.6630434782608695]
# 10 : [0.771117166212534, 0.6413043478260869]
# 11 : [0.7697547683923706, 0.6521739130434783]
# 12 : [0.7683923705722071, 0.6467391304347826]
# 13 : [0.7588555858310627, 0.6739130434782609]
# 14 : [0.7493188010899182, 0.6630434782608695]
# 15 : [0.7465940054495913, 0.6630434782608695]
# 16 : [0.7397820163487738, 0.6358695652173914]
# 17 : [0.7465940054495913, 0.6630434782608695]
# 18 : [0.7370572207084468, 0.6467391304347826]
# 19 : [0.7465940054495913, 0.6630434782608695]
# 20 : [0.7329700272479565, 0.6521739130434783]

# %%
import matplotlib.pyplot as plt

plt.scatter(K, training, color ='k')
plt.scatter(K, test, color ='g')
plt.show()

# %% [markdown]
# DecisionTree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)


training_score = clf.score(X_train, y_train)
test_score = clf.score(X_test, y_test)

print( f'Train: {training_score}' )
print( f'Test: {test_score}' )
# Out:
# Train: 1.0
# Test: 0.782608695652174

# %%
from sklearn import tree
tree.plot_tree(clf)
# Out:
# [Text(0.5475833333333333, 0.96875, 'x[10] <= 1.5\ngini = 0.496\nsamples = 734\nvalue = [333, 401]'),
#  Text(0.2885, 0.90625, 'x[2] <= 0.5\ngini = 0.305\nsamples = 427\nvalue = [80, 347]'),
#  Text(0.41804166666666664, 0.9375, 'True  '),
#  Text(0.129, 0.84375, 'x[1] <= 0.5\ngini = 0.177\nsamples = 296\nvalue = [29, 267]'),
#  Text(0.07466666666666667, 0.78125, 'x[9] <= 1.3\ngini = 0.387\nsamples = 42\nvalue = [11, 31]'),
#  Text(0.05333333333333334, 0.71875, 'x[0] <= 62.5\ngini = 0.48\nsamples = 25\nvalue = [10, 15]'),
#  Text(0.042666666666666665, 0.65625, 'x[6] <= 0.5\ngini = 0.494\nsamples = 18\nvalue = [10, 8]'),
#  Text(0.021333333333333333, 0.59375, 'x[3] <= 142.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.010666666666666666, 0.53125, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.032, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.064, 0.59375, 'x[7] <= 136.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.05333333333333334, 0.53125, 'x[4] <= 98.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.042666666666666665, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.064, 0.46875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.07466666666666667, 0.53125, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.064, 0.65625, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.096, 0.71875, 'x[3] <= 116.0\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.08533333333333333, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10666666666666667, 0.65625, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.18333333333333332, 0.78125, 'x[7] <= 175.5\ngini = 0.132\nsamples = 254\nvalue = [18, 236]'),
#  Text(0.17266666666666666, 0.71875, 'x[4] <= 170.5\ngini = 0.125\nsamples = 253\nvalue = [17, 236]'),
#  Text(0.128, 0.65625, 'x[10] <= 0.5\ngini = 0.024\nsamples = 81\nvalue = [1, 80]'),
#  Text(0.11733333333333333, 0.59375, 'x[6] <= 1.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.10666666666666667, 0.53125, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.128, 0.53125, 'x[5] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11733333333333333, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13866666666666666, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13866666666666666, 0.59375, 'gini = 0.0\nsamples = 72\nvalue = [0, 72]'),
#  Text(0.21733333333333332, 0.65625, 'x[4] <= 172.0\ngini = 0.169\nsamples = 172\nvalue = [16, 156]'),
#  Text(0.20666666666666667, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.228, 0.59375, 'x[7] <= 71.0\ngini = 0.16\nsamples = 171\nvalue = [15, 156]'),
#  Text(0.21733333333333332, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23866666666666667, 0.53125, 'x[9] <= 1.05\ngini = 0.151\nsamples = 170\nvalue = [14, 156]'),
#  Text(0.16, 0.46875, 'x[9] <= 0.15\ngini = 0.278\nsamples = 54\nvalue = [9, 45]'),
#  Text(0.14933333333333335, 0.40625, 'gini = 0.0\nsamples = 22\nvalue = [0, 22]'),
#  Text(0.17066666666666666, 0.40625, 'x[9] <= 0.55\ngini = 0.404\nsamples = 32\nvalue = [9, 23]'),
#  Text(0.144, 0.34375, 'x[5] <= 0.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.13333333333333333, 0.28125, 'x[0] <= 51.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.12266666666666666, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.144, 0.21875, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.15466666666666667, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.19733333333333333, 0.34375, 'x[6] <= 1.5\ngini = 0.227\nsamples = 23\nvalue = [3, 20]'),
#  Text(0.176, 0.28125, 'x[8] <= 0.5\ngini = 0.105\nsamples = 18\nvalue = [1, 17]'),
#  Text(0.16533333333333333, 0.21875, 'x[0] <= 54.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.15466666666666667, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.176, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.18666666666666668, 0.21875, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.21866666666666668, 0.28125, 'x[4] <= 256.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.208, 0.21875, 'x[0] <= 45.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.19733333333333333, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21866666666666668, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.22933333333333333, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.31733333333333336, 0.46875, 'x[3] <= 107.0\ngini = 0.082\nsamples = 116\nvalue = [5, 111]'),
#  Text(0.30666666666666664, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.328, 0.40625, 'x[0] <= 74.5\ngini = 0.067\nsamples = 115\nvalue = [4, 111]'),
#  Text(0.2986666666666667, 0.34375, 'x[7] <= 153.5\ngini = 0.052\nsamples = 113\nvalue = [3, 110]'),
#  Text(0.272, 0.28125, 'x[3] <= 112.0\ngini = 0.036\nsamples = 108\nvalue = [2, 106]'),
#  Text(0.25066666666666665, 0.21875, 'x[4] <= 218.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.24, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2613333333333333, 0.15625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.29333333333333333, 0.21875, 'x[3] <= 124.5\ngini = 0.019\nsamples = 102\nvalue = [1, 101]'),
#  Text(0.2826666666666667, 0.15625, 'x[6] <= 1.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.272, 0.09375, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.29333333333333333, 0.09375, 'x[0] <= 55.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2826666666666667, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.304, 0.03125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.304, 0.15625, 'gini = 0.0\nsamples = 85\nvalue = [0, 85]'),
#  Text(0.3253333333333333, 0.28125, 'x[7] <= 154.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.31466666666666665, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.336, 0.21875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.35733333333333334, 0.34375, 'x[9] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3466666666666667, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.368, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.194, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.448, 0.84375, 'x[1] <= 0.5\ngini = 0.475\nsamples = 131\nvalue = [51, 80]'),
#  Text(0.37066666666666664, 0.78125, 'x[3] <= 155.0\ngini = 0.366\nsamples = 29\nvalue = [22, 7]'),
#  Text(0.36, 0.71875, 'x[0] <= 53.5\ngini = 0.302\nsamples = 27\nvalue = [22, 5]'),
#  Text(0.34933333333333333, 0.65625, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.37066666666666664, 0.65625, 'x[9] <= 1.25\ngini = 0.459\nsamples = 14\nvalue = [9, 5]'),
#  Text(0.36, 0.59375, 'x[0] <= 64.0\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.34933333333333333, 0.53125, 'x[4] <= 301.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.33866666666666667, 0.46875, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.36, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.37066666666666664, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.38133333333333336, 0.59375, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.38133333333333336, 0.71875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5253333333333333, 0.78125, 'x[7] <= 136.5\ngini = 0.407\nsamples = 102\nvalue = [29, 73]'),
#  Text(0.4666666666666667, 0.71875, 'x[8] <= 0.5\ngini = 0.237\nsamples = 51\nvalue = [7.0, 44.0]'),
#  Text(0.424, 0.65625, 'x[5] <= 0.5\ngini = 0.401\nsamples = 18\nvalue = [5, 13]'),
#  Text(0.4026666666666667, 0.59375, 'x[4] <= 242.0\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.392, 0.53125, 'x[3] <= 112.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.38133333333333336, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4026666666666667, 0.46875, 'x[6] <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.392, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.41333333333333333, 0.40625, 'x[9] <= 0.35\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4026666666666667, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.424, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.41333333333333333, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.44533333333333336, 0.59375, 'x[6] <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.43466666666666665, 0.53125, 'x[7] <= 132.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.424, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.44533333333333336, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.456, 0.53125, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.5093333333333333, 0.65625, 'x[4] <= 317.0\ngini = 0.114\nsamples = 33\nvalue = [2, 31]'),
#  Text(0.488, 0.59375, 'x[3] <= 112.5\ngini = 0.062\nsamples = 31\nvalue = [1, 30]'),
#  Text(0.47733333333333333, 0.53125, 'x[4] <= 106.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.4666666666666667, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.488, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.49866666666666665, 0.53125, 'gini = 0.0\nsamples = 28\nvalue = [0, 28]'),
#  Text(0.5306666666666666, 0.59375, 'x[3] <= 125.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.52, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5413333333333333, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.584, 0.71875, 'x[10] <= 0.5\ngini = 0.491\nsamples = 51\nvalue = [22, 29]'),
#  Text(0.5626666666666666, 0.65625, 'x[3] <= 115.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.552, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5733333333333334, 0.59375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6053333333333333, 0.65625, 'x[9] <= 0.1\ngini = 0.47\nsamples = 45\nvalue = [17, 28]'),
#  Text(0.5946666666666667, 0.59375, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.616, 0.59375, 'x[9] <= 1.9\ngini = 0.492\nsamples = 39\nvalue = [17, 22]'),
#  Text(0.5946666666666667, 0.53125, 'x[0] <= 64.5\ngini = 0.493\nsamples = 25\nvalue = [14.0, 11.0]'),
#  Text(0.584, 0.46875, 'x[0] <= 59.5\ngini = 0.463\nsamples = 22\nvalue = [14, 8]'),
#  Text(0.5733333333333334, 0.40625, 'x[0] <= 54.5\ngini = 0.498\nsamples = 17\nvalue = [9, 8]'),
#  Text(0.552, 0.34375, 'x[4] <= 238.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.5413333333333333, 0.28125, 'x[0] <= 45.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.5306666666666666, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.552, 0.21875, 'x[7] <= 144.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5413333333333333, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5626666666666666, 0.15625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5626666666666666, 0.28125, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5946666666666667, 0.34375, 'x[6] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.584, 0.28125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6053333333333333, 0.28125, 'x[3] <= 62.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5946666666666667, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.616, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5946666666666667, 0.40625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6053333333333333, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6373333333333333, 0.53125, 'x[7] <= 157.5\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(0.6266666666666667, 0.46875, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.648, 0.46875, 'x[4] <= 227.0\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.6373333333333333, 0.40625, 'x[7] <= 171.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.6266666666666667, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.648, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6586666666666666, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8066666666666666, 0.90625, 'x[4] <= 42.5\ngini = 0.29\nsamples = 307\nvalue = [253, 54]'),
#  Text(0.677125, 0.9375, '  False'),
#  Text(0.7013333333333334, 0.84375, 'x[5] <= 0.5\ngini = 0.43\nsamples = 32\nvalue = [10, 22]'),
#  Text(0.6906666666666667, 0.78125, 'x[7] <= 102.5\ngini = 0.494\nsamples = 18\nvalue = [10, 8]'),
#  Text(0.68, 0.71875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7013333333333334, 0.71875, 'x[7] <= 155.0\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.6906666666666667, 0.65625, 'x[0] <= 44.0\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.6693333333333333, 0.59375, 'x[0] <= 42.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6586666666666666, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.68, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.712, 0.59375, 'x[0] <= 67.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.7013333333333334, 0.53125, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.7226666666666667, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.712, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.712, 0.78125, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.912, 0.84375, 'x[8] <= 0.5\ngini = 0.206\nsamples = 275\nvalue = [243, 32]'),
#  Text(0.8453333333333334, 0.78125, 'x[9] <= 2.4\ngini = 0.13\nsamples = 244\nvalue = [227, 17]'),
#  Text(0.8346666666666667, 0.71875, 'x[0] <= 56.5\ngini = 0.116\nsamples = 242\nvalue = [227, 15]'),
#  Text(0.7866666666666666, 0.65625, 'x[6] <= 0.5\ngini = 0.06\nsamples = 195\nvalue = [189, 6]'),
#  Text(0.7546666666666667, 0.59375, 'x[4] <= 188.0\ngini = 0.269\nsamples = 25\nvalue = [21, 4]'),
#  Text(0.744, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7653333333333333, 0.53125, 'x[2] <= 0.5\ngini = 0.159\nsamples = 23\nvalue = [21, 2]'),
#  Text(0.7546666666666667, 0.46875, 'x[0] <= 47.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.744, 0.40625, 'x[7] <= 169.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7333333333333333, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7546666666666667, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7653333333333333, 0.40625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.776, 0.46875, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.8186666666666667, 0.59375, 'x[2] <= 0.5\ngini = 0.023\nsamples = 170\nvalue = [168, 2]'),
#  Text(0.808, 0.53125, 'x[0] <= 51.5\ngini = 0.108\nsamples = 35\nvalue = [33, 2]'),
#  Text(0.7973333333333333, 0.46875, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(0.8186666666666667, 0.46875, 'x[0] <= 52.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.808, 0.40625, 'x[7] <= 153.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7973333333333333, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8186666666666667, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8293333333333334, 0.40625, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.8293333333333334, 0.53125, 'gini = 0.0\nsamples = 135\nvalue = [135, 0]'),
#  Text(0.8826666666666667, 0.65625, 'x[7] <= 151.5\ngini = 0.31\nsamples = 47\nvalue = [38, 9]'),
#  Text(0.8613333333333333, 0.59375, 'x[0] <= 57.5\ngini = 0.08\nsamples = 24\nvalue = [23, 1]'),
#  Text(0.8506666666666667, 0.53125, 'x[7] <= 140.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.84, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8613333333333333, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.872, 0.53125, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.904, 0.59375, 'x[7] <= 170.0\ngini = 0.454\nsamples = 23\nvalue = [15, 8]'),
#  Text(0.8933333333333333, 0.53125, 'x[4] <= 318.5\ngini = 0.498\nsamples = 17\nvalue = [9, 8]'),
#  Text(0.8826666666666667, 0.46875, 'x[5] <= 0.5\ngini = 0.459\nsamples = 14\nvalue = [9, 5]'),
#  Text(0.872, 0.40625, 'x[0] <= 61.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.8613333333333333, 0.34375, 'x[7] <= 160.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.8506666666666667, 0.28125, 'x[7] <= 157.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.84, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8613333333333333, 0.21875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.872, 0.28125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8826666666666667, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8933333333333333, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.904, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9146666666666666, 0.53125, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.856, 0.71875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9786666666666667, 0.78125, 'x[2] <= 0.5\ngini = 0.499\nsamples = 31\nvalue = [16, 15]'),
#  Text(0.968, 0.71875, 'x[9] <= 0.7\ngini = 0.454\nsamples = 23\nvalue = [8, 15]'),
#  Text(0.9573333333333334, 0.65625, 'x[0] <= 65.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.9466666666666667, 0.59375, 'x[7] <= 155.0\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.936, 0.53125, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9573333333333334, 0.53125, 'x[7] <= 162.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.9466666666666667, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.968, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.968, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9786666666666667, 0.65625, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.9893333333333333, 0.71875, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]')]

# %% [markdown]
# ![Untitled.png](data:image/png;base64,...)

# %%
from sklearn.metrics import accuracy_score
y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.782608695652174

# %%
from sklearn.model_selection import GridSearchCV

#Hyperparameter to fine tune
param_grid = {
    'max_depth': range(1, 10, 1),
    'min_samples_leaf': range(1, 20, 2),
    'min_samples_split': range(2, 20, 2),
    'criterion': ["entropy", "gini"]
}
#Decision tree classifier
tree = DecisionTreeClassifier(random_state=42)
#GridSearchCV
grid_search = GridSearchCV(estimator=tree, param_grid=param_grid,
                           cv=5, verbose=True)
grid_search.fit(X_train, y_train)

#Best score and estimator
print("best accuracy", grid_search.best_score_)
print(grid_search.best_estimator_)
# Out:
# Fitting 5 folds for each of 1620 candidates, totalling 8100 fits
# best accuracy 0.8337992731339112
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_split=16,
#                        random_state=42)

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score

# %%
#Do some Naive Bayes here

nb = GaussianNB()
nb.fit(X_train, y_train)

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# %%
#Evaluate your model and compare it to the other models (Decision Trees and KNN)
#Using your understanding of the data, explain which model you think is best
#(hint: look at the different measures and stuff like FN and FP)
